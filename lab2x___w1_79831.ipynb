# %% [markdown]
# ## Zadanie
#
# Utwórz string `s1` będący powtórzeniem Twojego imienia i nazwiska tyle razy ile wynosi reszta z dzielenia wartości Twojego numeru indeksu przez `99` (jeśli reszta wynosi `0`, to znajdź resztę z dzielenia przez `999`)
#
#
# ```
# przykład:
# nr_indeksu, imie, nazwisko = 99003, 'Błażej', 'Kuś'
# s1: BłażejKuśBłażejKuśBłażejKuś
# ```
#
# Napisz funkcję `f1` przyjmującą jako argument `s1` i zwracającą dwie listy:
# `x` - lista zawierająca co trzecią literę z `s1` od początku
# `y` - lista zawierająca co trzecią literę z `s1` od końca
#
# uwaga: `(type(x): <class 'list'>)`, `(type(y): <class 'list'>)`
#
#
# ```
# przykład:
# x: ['B', 'ż', 'K', 'B', 'ż', 'K', 'B', 'ż', 'K']
# y: ['ś', 'j', 'a', 'ś', 'j', 'a', 'ś', 'j', 'a']
# ```
#
# Następnie utwórz listę `z` zawierającą elementy z `x` i `y` będące znakami ASCII (kod <= 127)
#
# **znajdź:**
# `w1`, będące sumą wszystkich znaków z listy `z` (sumą ich kodów)

# %%
# Podmień wartości poniższych zmiennych na Twoje personalia.
# Imie i Nazwisko proszę pisać z polskimi literami i zaczynać od dużej litery.
nr_indeksu, imie, nazwisko = 158200, 'Piotr', 'Niepsuj'

reszta = nr_indeksu % 99
if reszta == 0:
    reszta = nr_indeksu % 999

s1 = (imie + nazwisko) * reszta

def f1(s1: str) -> tuple[list[str], list[str]]:
    return list(s1[::3]), list(s1[::-3])

x, y = f1(s1)

z = [char for char in x + y if ord(char) <= 127]

w1 = sum(ord(char) for char in z)

print(f"s1: {s1}")
print(f"x: {x}")
print(f"y: {y}")
print(f"z: {z}")
print(f"w1: {w1}")
# Out:
# s1: ...
# x: ['P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's']
# y: ['j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o']
# z: ['P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'P', 't', 'i', 's', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o', 'j', 'p', 'N', 'o']
# w1: 79831

# %%
# przykład generowania zwracaanej nazwy tego notebooka
# zamiast 999 wpisz obliczone przez Ciebie wartości

w1 = 79831

nazwa_notebooka = f'lab2x___w1_{w1}.ipynb'
print(f'nazwa_notebooka: {nazwa_notebooka}')
# Out:
# nazwa_notebooka: lab2x___w1_79831.ipynb
